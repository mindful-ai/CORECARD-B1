# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 1. Basic Plot

# %%
x = np.linspace(0, 5, 11)
x

# %%
y = x ** 2
y

# %%
plt.plot(x, y, color='r')
plt.xlabel("X")
plt.ylabel("Y")
plt.title("My first graph")

# %% [markdown]
# ##### Subplots

# %%
plt.subplot(2, 2, 1)
plt.plot(x, y, color='r')
plt.subplot(2, 2, 4)
plt.plot(y, x, color='b')

# %% [markdown]
# ### 2. Object Oriented Style of Plotting

# %%
fig = plt.figure() # create the figure object

axes1 = fig.add_axes([0.2, 0.2, 0.8, 0.8])
axes1.plot(x, y, color='r')
axes1.set_title('First Axes')
axes1.set_xlabel('X')
axes1.set_ylabel('Y')

axes2 = fig.add_axes([1.2, 0.5, 0.4, 0.4])
axes2.plot(y, x, color='b')
axes2.set_title('Second Axes')
axes2.set_xlabel('Y')
axes2.set_ylabel('X')

# %% [markdown]
# ##### Subplots

# %%
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# %%
fig, axes = plt.subplots()
axes.plot(x, y)

# %%
f, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x, y, color='r')
axes[1].plot(y, x, color='b')

# %% [markdown]
# ##### Figure Size, DPI

# %%
fig, axes = plt.subplots(figsize=(8, 6), dpi=100)
axes.plot(x, y)

# %% [markdown]
# ##### Legends

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x, x**2, color='b', label='x square')
ax.plot(x, x**3, color='r', label='x cube')
ax.legend(loc=4)

# %% [markdown]
# ##### Set colors, line types and line widths

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, 'b.-') # blue line with dots
ax.plot(x, x**3, 'g--') # green dashed line

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, color="blue", linewidth=5.25) # blue line with dots
ax.plot(x, x**3, color='r', linewidth=1.25) # green dashed line
ax.plot(x, x**4, color='#089056', linewidth=2.25)

# %%
fig, ax = plt.subplots(figsize=(12,6))

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# %%
fig, ax = plt.subplots(figsize=(12,6))
# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor='r')
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %% [markdown]
# ##### Plot range

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");
